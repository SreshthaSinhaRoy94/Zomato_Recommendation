# %% [markdown]
# #### importing libraries

# %%
import pandas as pd
import bs4
import selenium
import requests
import urllib
import csv
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# #### reading the zomato url

# %%
from selenium import webdriver
browser = webdriver.Chrome('chromedriver.exe')
url1 = 'https://www.zomato.com/bangalore/great-food-no-bull'
browser.get(url1)

# %%
urls = browser.find_elements_by_css_selector('div.relative.top-res-box.entity-ads-snippet-track')

# %% [markdown]
# #### From this URL (https://www.zomato.com/bangalore/great-food-no-bull), scrape the following information and store them in a data frame
# #### Restaurant Name
# #### URL to the restaurant

# %%
urls_df = pd.DataFrame(columns=['Restaurant_Name', 'URL'])
for elem in urls:
    url = elem.find_element_by_css_selector('a')
    url = url.get_attribute('href')
    rest_name = elem.find_element_by_css_selector('div.res_title')
    rest_name = rest_name.get_attribute('innerHTML')
    curr_row = {
        'URL' : url, 
        'Restaurant_Name' : rest_name
    }
    
    urls_df = urls_df.append(curr_row,ignore_index = True)
    urls_df['Restaurant_Name'] = urls_df['Restaurant_Name'].str.replace('\n','')
    row = [url,rest_name.strip()]
    with open('rest.csv', 'a', newline = '') as csvFile: ### writing the dataframe to a csv file
        writer = csv.writer(csvFile)
        writer.writerow(row)

# %%
urls_df
# Out:
#                                        Restaurant_Name  \
# 0                                       MISU
# 1                           Buff Buffet Buff
# 2                           One For The Road
# 3                              Delhi Highway
# 4                                  Red Rhino
# 5                   Brew and Barbeque - A...
# 6                   Barbecue by Punjab Grill
# 7                                 Bamboo Hut
# 8                                 Polar Bear
# 9                             PurpleBasil.in
# 10                               IceBreakers
# 11                                   BelgYum
# 12                                  Galito's
# 13               Byg Brewski Brewing Company
# 14                          Smoke House Deli
# 15               Republic Of Noodles - Lemon...    ...
# 16                                   Lavonne
# 17                Sidewalk Bar &amp; Kitchen
# 18                                   BITEBOX
# 19                            Mainland China
# 20                         Toast &amp; Tonic
# 21                Fenny's Lounge And Kitchen
# 22                               Pin Me Down
# 23                              Punjab Grill
# 24                               Suryawanshi
# 25                              Market Table
# 26                                Caperberry
# 27                     Rim Naam - The Oberoi
# 28                              Pasta Street
# 29                      Avista Cafe Pizzeria
# ..                                                 ...
# 111                         Sharon Tea Stall
# 112                                    HOMMS
# 113                                      OKI
# 114                     Windmills Craftworks
# 115                           The Globe Grub
# 116                        Once Upon A Flame
# 117                            XOOX Brewmill
# 118                    Brewklyn Microbrewery
# 119                            Arogya Ahaara
# 120                AB's - Absolute Barbecues
# 121                The Hole in the Wall Cafe
# 122                                   Social
# 123                                  eat.fit
# 124                                 HVR Veg
# 125              Bloomsbury's Global Kitchen...    ...
# 126                  Belgian Waffle Factory
# 127                             Nasi And Mee
# 128                                Brik Oven
# 129                        Rolls &amp; Bowls
# 130                             Dyu Art Cafe
# 131                        Natural Ice Cream
# 132                               Jalsa Gold
# 133                   Corner House Ice Cream
# 134                         Milano Ice Cream
# 135              Karavalli - The Gateway Hotel     ...
# 136                        Empire Restaurant
# 137                                Communiti
# 138              Drunkling - Sizzlers and Pub      ...
# 139                                   Stoner
# 140                           TBC Sky Lounge
#
#                                                    URL
# 0    https://www.zomato.com/bangalore/misu-st-marks...
# 1    https://www.zomato.com/bangalore/buff-buffet-b...
# 2    https://www.zomato.com/bangalore/one-for-the-r...
# 3    https://www.zomato.com/bangalore/delhi-highway...
# 4    https://www.zomato.com/bangalore/red-rhino-whi...
# 5    https://www.zomato.com/bangalore/brew-and-barb...
# 6    https://www.zomato.com/bangalore/barbecue-by-p...
# 7    https://www.zomato.com/bangalore/bamboo-hut-na...
# 8    https://www.zomato.com/bangalore/restaurants/p...
# 9    https://www.zomato.com/bangalore/purplebasil-i...
# 10   https://www.zomato.com/bangalore/icebreakers-k...
# 11   https://www.zomato.com/bangalore/belgyum-white...
# 12   https://www.zomato.com/bangalore/restaurants/g...
# 13   https://www.zomato.com/bangalore/restaurants/b...
# 14   https://www.zomato.com/bangalore/restaurants/s...
# 15   https://www.zomato.com/bangalore/republic-of-n...
# 16   https://www.zomato.com/bangalore/lavonne-indir...
# 17   https://www.zomato.com/bangalore/sidewalk-bar-...
# 18   https://www.zomato.com/bangalore/bitebox-marat...
# 19   https://www.zomato.com/bangalore/restaurants/m...
# 20   https://www.zomato.com/bangalore/toast-tonic-r...
# 21   https://www.zomato.com/bangalore/fennys-lounge...
# 22   https://www.zomato.com/bangalore/pin-me-down-b...
# 23   https://www.zomato.com/bangalore/punjab-grill-...
# 24   https://www.zomato.com/bangalore/suryawanshi-s...
# 25   https://www.zomato.com/bangalore/market-table-...
# 26   https://www.zomato.com/bangalore/caperberry-la...
# 27   https://www.zomato.com/bangalore/rim-naam-the-...
# 28   https://www.zomato.com/bangalore/restaurants/p...
# 29   https://www.zomato.com/bangalore/avista-cafe-p...
# ..                                                 ...
# 111  https://www.zomato.com/bangalore/sharon-tea-st...
# 112  https://www.zomato.com/bangalore/homms-maratha...
# 113  https://www.zomato.com/bangalore/oki-1-kammana...
# 114  https://www.zomato.com/bangalore/windmills-cra...
# 115  https://www.zomato.com/bangalore/the-globe-gru...
# 116  https://www.zomato.com/bangalore/once-upon-a-f...
# 117  https://www.zomato.com/bangalore/xoox-brewmill...
# 118  https://www.zomato.com/bangalore/brewklyn-micr...
# 119  https://www.zomato.com/bangalore/arogya-ahaara...
# 120  https://www.zomato.com/bangalore/restaurants/a...
# 121  https://www.zomato.com/bangalore/the-hole-in-t...
# 122  https://www.zomato.com/bangalore/restaurants/s...
# 123  https://www.zomato.com/bangalore/restaurants/e...
# 124  https://www.zomato.com/bangalore/hvr-veg-sesha...
# 125  https://www.zomato.com/bangalore/bloomsburys-g...
# 126  https://www.zomato.com/bangalore/restaurants/b...
# 127  https://www.zomato.com/bangalore/nasi-and-mee-...
# 128  https://www.zomato.com/bangalore/brik-oven-chu...
# 129  https://www.zomato.com/bangalore/rolls-bowls-b...
# 130  https://www.zomato.com/bangalore/dyu-art-cafe-...
# 131  https://www.zomato.com/bangalore/restaurants/n...
# 132  https://www.zomato.com/bangalore/jalsa-gold-ma...
# 133  https://www.zomato.com/bangalore/restaurants/c...
# 134  https://www.zomato.com/bangalore/restaurants/m...
# 135  https://www.zomato.com/bangalore/karavalli-the...
# 136  https://www.zomato.com/bangalore/empire-restau...
# 137  https://www.zomato.com/bangalore/communiti-res...
# 138  https://www.zomato.com/bangalore/drunkling-siz...
# 139  https://www.zomato.com/bangalore/stoner-korama...
# 140  https://www.zomato.com/bangalore/restaurants/t...
#
# [141 rows x 2 columns]

# %% [markdown]
# #### Loop through each restaurant(atleast 50) and do the following
# #### scrape sample reviews, make sure you click the load more button continuously in a loop until all reviews are loaded
# #### From each review extract the following
# #### Reviewer name
# #### Reviewer ID
# #### Ratings

# %%
reviews_df = pd.DataFrame(columns=['Restaurant_name','User_ID','User_Name','Rating']) #,'Reviews'
for a,elem1 in urls_df.iterrows():
    try: ## to catch the exceptions that we get while scraping data from restaurants(to skp these kind of restaurantsS)
        browser.get(elem1['URL'])
        rest_name = elem1['Restaurant_Name']
        while(True): ### load more
            try:
                more_sel = 'div.load-more'
                load_more_button = browser.find_element_by_css_selector(more_sel)
                load_more_button.click()
            except Exception:
                break;
        reviews = browser.find_elements_by_css_selector('div.ui.segment.clearfix.brtop')
        for elem in reviews:
            name = elem.find_element_by_css_selector('a[data-entity_id]')
            uid = name.get_attribute('data-entity_id')
            name = name.get_attribute('innerHTML')#.splitlines()[1]
            rating =  elem.find_element_by_css_selector('div[aria-label]')
            rating = rating.get_attribute('aria-label')
            curr_row = {
                'Restaurant_name' : rest_name,
                'User_ID' : uid,
                'User_Name': name,
                'Rating' : rating,
                #'Reviews' : rev
            }

            reviews_df = reviews_df.append(curr_row,ignore_index = True)
            reviews_df['Rating'] = reviews_df['Rating'].str.replace('[^0-9.]','')
            reviews_df['User_Name'] = reviews_df['User_Name'].str.replace('[^a-zA-Z]','')
            #reviews_df['Reviews'] = reviews_df['Reviews'].str.replace('[^a-zA-Z0-9 ]','')
            #reviews_df['Reviews'] = reviews_df['Reviews'].str.replace('RATED','')
            row = [rest_name.strip(), uid,name.strip(),rating]
            with open('review.csv', 'a', newline='') as csvFile: ### writing the dataframe to a csv file
                writer = csv.writer(csvFile)
                writer.writerow(row)
    except Exception:
                continue
    if(str(a)=='70'): ### restricting the data to 70 rows so that we get details of atleast 50 restaurants
        break

# %% [markdown]
# #### writing the data from dataframe to a csv file

# %%
reviews = pd.read_csv('review.csv', encoding = "latin")
reviews.head()

# %% [markdown]
# #### pivot table for the reviews DF

# %%
user_item_matrix = reviews.pivot_table(index='User_ID',
                   columns = 'Restaurant_Name',
                   values='Rating')
print(user_item_matrix.shape)
user_item_matrix.head()

# %% [markdown]
# ####  Perform exploratory data analysis using the above data

# %%
# 1. Avg no. of ratings per user

user_item_matrix.count(axis=1).mean() ## per user avg

# %%
# 2. User with most no. of ratings

user_item_matrix.count(axis=1).sort_values(ascending = False).head(1)

# %%
# 3. Avg rating per restaurant

user_item_matrix.count().mean()

# %%
# 4. Restaurant with most no. of ratings

user_item_matrix.count().sort_values(ascending = False).head(1)

# %%
## cosine_similarity does not accept missing values
 
ui_matrix = user_item_matrix.apply(lambda v: v - v.mean(), axis = 1).fillna(0)

# %%
sim_matrix = pd.DataFrame(cosine_similarity(ui_matrix),
            index = ui_matrix.index,
            columns=ui_matrix.index)

# %%
sim_matrix

# %%
User the above data, build a recommendation engine using User Based Collaborative Filtering. 
Create a function which takes User ID as input and return 3 restaurants that you would recommend to the user.

# %%
def ubcf(userid): 
    preds = pd.DataFrame(columns=['rname', 'predicted_rating'])
    neighs_user = sim_matrix[userid].drop(userid).sort_values(ascending = False).head(7).index
    for rname, rating in user_item_matrix.loc[userid].items(): 
        if pd.isnull(rating):
            rname_ratings = user_item_matrix.loc[neighs_user, rname]
            avg_rname_rating = rname_ratings.mean() # predicting the rating for the restaurants based on the avg rating given by neighbours
            preds = preds.append({'rname' : rname,
                                 'predicted_rating': avg_rname_rating},
                                 ignore_index = True)
            rest_recom = preds.sort_values('predicted_rating', ascending=False).head(3)['rname']
    return rest_recom.values.tolist()

# %% [markdown]
# #### Sample input and output

# %%
ubcf(19800)
